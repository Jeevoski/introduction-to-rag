# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

# 1. Load variables from .env
load_dotenv()

# 2. Get API key from environment
api_key = os.getenv("GEMINI_API_KEY")
if not api_key:
    raise RuntimeError("GEMINI_API_KEY is not set")

# 3. Initialize OpenAI client with Google's base URL
client = OpenAI(
    api_key=api_key,
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# 4. Make test call with a supported Gemini model identifier
response = client.chat.completions.create(
    model="gemini-flash-latest",
    messages=[{"role": "user", "content": "Hello! Confirm if this key works."}]
)

print(response.choices[0].message.content)
# Out:
# Hello! It looks like you didn't include the key in your message.
#
# Please paste or provide the key (and let me know what kind of key it is, e.g., API key, JSON web token, SSH key, etc.), and I'll be happy to help you validate or test it!
#
# *(Note: For your own security, please make sure not to share real, sensitive private keys or production credentials.)*
